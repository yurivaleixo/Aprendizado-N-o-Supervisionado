# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/Trabalho Data Science 2 Bim/FIFA_data.csv',
                    sep=',', encoding='UTF-8')

# %%
df.head()
# Out:
#    ï»¿      ID               Name  Age  \
# 0    0  158023           L. Messi   31
# 1    1   20801  Cristiano Ronaldo   33
# 2    2  190871          Neymar Jr   26
# 3    3  193080             De Gea   27
# 4    4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df = df.drop("Unnamed: 0", axis='columns')

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df = df.drop(['Jersey Number','Joined','Loaned From','Contract Valid Until','LS','ST',
              ], axis=1)

# %%
df.head()
# Out:
#        ID               Name  Age  Overall                 Club    Value  \
# 0  158023           L. Messi   31       94         FC Barcelona  €110.5M
# 1   20801  Cristiano Ronaldo   33       94             Juventus     €77M
# 2  190871          Neymar Jr   26       92  Paris Saint-Germain  €118.5M
# 3  193080             De Gea   27       91    Manchester United     €72M
# 4  192985       K. De Bruyne   27       91      Manchester City    €102M
#
#     Wage Preferred Foot Height  Weight
# 0  €565K           Left    5'7  159lbs
# 1  €405K          Right    6'2  183lbs
# 2  €290K          Right    5'9  150lbs
# 3  €260K          Right    6'4  168lbs
# 4  €355K          Right   5'11  154lbs

# %%
df.isnull().sum()
# Out:
# ID                  0
# Name                0
# Age                 0
# Overall             0
# Club              241
# Value               0
# Wage                0
# Preferred Foot     48
# Height             48
# Weight             48
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#            ID            Name  Age  Overall Club Value Wage Preferred Foot  \
# 452    207439      L. Paredes   24       80  NaN   € 0  € 0          Right
# 538    156713    A. Granqvist   33       80  NaN   € 0  € 0          Right
# 568    229909        A. Lunev   26       79  NaN   € 0  € 0          Right
# 677    187347    I. Smolnikov   29       79  NaN   € 0  € 0          Right
# 874    187607       A. Dzyuba   29       78  NaN   € 0  € 0          Right
# ...       ...             ...  ...      ...  ...   ...  ...            ...
# 17197  245164        V. Kaith   21       55  NaN   € 0  € 0          Right
# 17215  243131        K. Taimi   26       55  NaN   € 0  € 0          Right
# 17339  233526        S. Passi   23       54  NaN   € 0  € 0          Right
# 17436  236452  D. Lalhlimpuia   20       54  NaN   € 0  € 0          Right
# 17539  234508        C. Singh   21       53  NaN   € 0  € 0          Right
#
#       Height  Weight
# 452     5'11  165lbs
# 538      6'4  185lbs
# ...

# %%
df.dropna(inplace=True)

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Overall, Club, Value, Wage, Preferred Foot, Height, Weight]
# Index: []

# %%
df.head()
# Out:
#        ID               Name  Age  Overall                 Club    Value  \
# 0  158023           L. Messi   31       94         FC Barcelona  €110.5M
# 1   20801  Cristiano Ronaldo   33       94             Juventus     €77M
# 2  190871          Neymar Jr   26       92  Paris Saint-Germain  €118.5M
# 3  193080             De Gea   27       91    Manchester United     €72M
# 4  192985       K. De Bruyne   27       91      Manchester City    €102M
#
#     Wage Preferred Foot Height  Weight
# 0  €565K           Left    5'7  159lbs
# 1  €405K          Right    6'2  183lbs
# 2  €290K          Right    5'9  150lbs
# 3  €260K          Right    6'4  168lbs
# 4  €355K          Right   5'11  154lbs

# %%
df.isnull().sum()
# Out:
# ID                0
# Name              0
# Age               0
# Overall           0
# Club              0
# Value             0
# Wage              0
# Preferred Foot    0
# Height            0
# Weight            0
# dtype: int64

# %%
df.to_csv('/content/drive/MyDrive/Trabalho Data Science 2 Bim/FIFA_data-limpo.csv', index=False)
